# %%
# Import essential libraries for authentication
# Spotipy is the go-to Python wrapper for the Spotify API
# Spotify uses OAuth 2.0, so we will import that
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MultiLabelBinarizer
import time
import requests
import numpy as np

# Used to hide credentials
from dotenv import load_dotenv
import os

# FastAPI import
from fastapi import APIRouter

# %%
# Authentication via spotipy.Spotify()
load_dotenv()
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=os.getenv("SPOTIFY_CLIENT_ID"),
    client_secret=os.getenv("SPOTIFY_CLIENT_SECRET"),
    redirect_uri=os.getenv("SPOTIFY_REDIRECT_URI"),
    scope="user-library-read user-top-read user-read-recently-played"
))

# %% [markdown]
# ## Step 1: Pull Listening Data
# Fetch liked songs, top tracks (short + medium term), and recently played.

# %%
# Pull and store music data from multiple sources
# i.e. Liked Songs, Top Tracks/Artists, and Recently Played"
# Starting with Liked Songs
def get_liked_songs(sp):
    results = sp.current_user_saved_tracks(limit=50)
    tracks = []
    while results:
        for item in results['items']:
            track = item['track']
            if track is None:        # skip any null tracks
                continue
            tracks.append({
                'id': track['id'],
                'name': track['name'],
                'artist': track['artists'][0]['name'],
                'artist_id': track['artists'][0]['id'],
                'popularity': track.get('popularity', 0), # default to 0 if missing
                'source': 'liked'
        })
        results = sp.next(results)  # handles pagination
    return tracks

# Top Tracks
# time_range options:
# - 'short_term'  = last 4 weeks
# - 'medium_term' = last 6 months (default)
# - 'long_term'   = all time
def get_top_tracks(sp, time_range='medium_term', limit=50):
    results = sp.current_user_top_tracks(
        time_range=time_range,
        limit=limit
    )
    tracks = []
    for item in results['items']:
        tracks.append({
            'id': item['id'],
            'name': item['name'],
            'artist': item['artists'][0]['name'],
            'artist_id': item['artists'][0]['id'],
            'popularity': item.get('popularity', 0), # default to 0 if missing
            'source': f'top_tracks_{time_range}'
        })
    return tracks

# Top artists
# Useful for seeding recommendations
# and filtering candidates by genre
def get_top_artists(sp, time_range='medium_term', limit=50):
    results = sp.current_user_top_artists(
        time_range=time_range,
        limit=limit
    )
    artists = []
    for item in results['items']:
        artists.append({
            'id': item['id'],
            'name': item['name'],
            'genres': item.get('genres', []),
            'popularity': item.get('popularity', 0), # default to 0 if missing
            'source': f'top_artists_{time_range}'
        })
    return artists

# Lastly, get recently played
def get_recently_played(sp, limit=50):
    results = sp.current_user_recently_played(limit=limit)
    tracks = []
    for item in results['items']:
        track = item['track']
        if track is None:        # skip any null tracks
                continue
        tracks.append({
            'id': track['id'],
            'name': track['name'],
            'artist': track['artists'][0]['name'],
            'artist_id': track['artists'][0]['id'],
            'played_at': item['played_at'],   # timestamp — useful for weighting
            'source': 'recently_played'
        })
    return tracks

# Combine liked songs, top tracks, and recently played
# To make a cohesive taste profile for the user
def get_full_taste_profile(sp):
    all_tracks = (
        get_liked_songs(sp) +
        get_top_tracks(sp, 'short_term') +
        get_top_tracks(sp, 'medium_term') +
        get_recently_played(sp)
    )
    seen = set()
    unique = []
    for t in all_tracks:
        if t['id'] not in seen:
            seen.add(t['id'])
            unique.append(t)
    return unique

tracks = get_full_taste_profile(sp)
print(f"Total unique tracks in taste profile: {len(tracks)}")
# Out:
# Total unique tracks in taste profile: 933

# %% [markdown]
# ## Step 2: Last.fm Tag Features
# Since Spotify's audio features endpoint is restricted for new apps,
# we use Last.fm tags as our feature vectors instead. Last.fm tags
# include genre, mood, and style descriptors like 'indie', 'chill',
# 'melancholic', 'acoustic', etc. — providing richer features than
# genre alone.

# %%
LASTFM_API_KEY = os.getenv("LASTFM_API_KEY")
LASTFM_BASE_URL = "http://ws.audioscrobbler.com/2.0/"

def get_lastfm_tags(artist, track, max_tags=5):
    try:
        response = requests.get(LASTFM_BASE_URL, params={
            "method": "track.getTopTags",
            "artist": artist,
            "track": track,
            "api_key": LASTFM_API_KEY,
            "format": "json"
        }, timeout=5)
        data = response.json()
        if 'error' in data or 'toptags' not in data:
            return get_lastfm_artist_tags(artist, max_tags)
        tags = [
            t['name'].lower().strip()
            for t in data['toptags']['tag']
            if int(t.get('count', 0)) > 10
        ]
        return tags[:max_tags]
    except Exception as e:
        print(f"Failed for {artist} - {track}: {e}")
        return []

def get_lastfm_artist_tags(artist, max_tags=5):
    try:
        response = requests.get(LASTFM_BASE_URL, params={
            "method": "artist.getTopTags",
            "artist": artist,
            "api_key": LASTFM_API_KEY,
            "format": "json"
        }, timeout=5)
        data = response.json()
        if 'error' in data or 'toptags' not in data:
            return []
        tags = [
            t['name'].lower().strip()
            for t in data['toptags']['tag']
            if int(t.get('count', 0)) > 10
        ]
        return tags[:max_tags]
    except Exception as e:
        print(f"Artist fallback failed for {artist}: {e}")
        return []

def get_lastfm_features(tracks, max_tags=5):
    track_tags = []
    total = len(tracks)
    for i, track in enumerate(tracks):
        tags = get_lastfm_tags(track['artist'], track['name'], max_tags)
        track_tags.append(tags)
        if (i + 1) % 10 == 0:
            print(f"Processed {i + 1}/{total} tracks...")
        time.sleep(0.25)
    filled = sum(1 for t in track_tags if len(t) > 0)
    print(f"\nTracks with tags: {filled}/{total}")
    mlb = MultiLabelBinarizer()
    tag_matrix = mlb.fit_transform(track_tags)
    return tag_matrix, mlb, track_tags

tag_matrix, mlb, track_tags = get_lastfm_features(tracks)
print(f"Tag matrix shape: {tag_matrix.shape}")
print(f"Total unique tags found: {len(mlb.classes_)}")
# Out:
# Processed 10/933 tracks...
# Processed 20/933 tracks...
# Processed 30/933 tracks...
# Processed 40/933 tracks...
# Processed 50/933 tracks...
# Processed 60/933 tracks...
# Processed 70/933 tracks...
# Processed 80/933 tracks...
# Processed 90/933 tracks...
# Processed 100/933 tracks...
# Failed for Taylor Swift - Blank Space: HTTPConnectionPool(host='ws.audioscrobbler.com', port=80): Read timed out. (read timeout=5)
# Processed 110/933 tracks...
# Processed 120/933 tracks...
# Processed 130/933 tracks...
# Processed 140/933 tracks...
# Processed 150/933 tracks...
# Processed 160/933 tracks...
# Processed 170/933 tracks...
# Processed 180/933 tracks...
# Processed 190/933 tracks...
# Processed 200/933 tracks...
# Processed 210/933 tracks...
# Processed 220/933 tracks...
# Processed 230/933 tracks...
# Processed 240/933 tracks...
# Processed 250/933 tracks...
# Processed 260/933 tracks...
# Processed 270/933 tracks...
# Processed 280/933 tracks...
# Failed for Hxzz - Patience: HTTPConnectionPool(host='ws.audioscrobbler.com', port=80): Read timed out. (read timeout=5)
# Processed 290/933 tracks...
# Processed 300/933 tracks...
# Processed 310/933 tracks...
# Processed 320/933 tracks...
# Processed 330/933 tracks...
# Processed 340/933 tracks...
# Failed for VK Blanka - Black Catcher: HTTPConnectionPool(host='ws.audioscrobbler.com', port=80): Read timed out. (read timeout=5)
# Processed 350/933 tracks...
# Processed 360/933 tracks...
# Processed 370/933 tracks...
# Processed 380/933 tracks...
# Processed 390/933 tracks...
# Processed 400/933 tracks...
# Processed 410/933 tracks...
# Processed 420/933 tracks...
# Processed 430/933 tracks...
# Processed 440/933 tracks...
# Failed for DYES IWASAKI - Reflection: HTTPConnectionPool(host='ws.audioscrobbler.com', port=80): Read timed out. (read timeout=5)
# Processed 450/933 tracks...
# Processed 460/933 tracks...
# Processed 470/933 tracks...
# Processed 480/933 tracks...
# Processed 490/933 tracks...
# Processed 500/933 tracks...
# Processed 510/933 tracks...
# Processed 520/933 tracks...
# Processed 530/933 tracks...
# Processed 540/933 tracks...
# Processed 550/933 tracks...
# Processed 560/933 tracks...
# Processed 570/933 tracks...
# Processed 580/933 tracks...
# Processed 590/933 tracks...
# Processed 600/933 tracks...
# Processed 610/933 tracks...
# Processed 620/933 tracks...
# Failed for ZAQ - Sparkling Daydream: HTTPConnectionPool(host='ws.audioscrobbler.com', port=80): Read timed out. (read timeout=5)
# Processed 630/933 tracks...
# Failed for SID - Alibi: HTTPConnectionPool(host='ws.audioscrobbler.com', port=80): Read timed out. (read timeout=5)
# Processed 640/933 tracks...
# Failed for Aimer - LAST STARDUST: HTTPConnectionPool(host='ws.audioscrobbler.com', port=80): Read timed out. (read timeout=5)
# Processed 650/933 tracks...
# Failed for Bankrol Hayden - Costa Rica (feat. The Kid LAROI) - Remix: HTTPConnectionPool(host='ws.audioscrobbler.com', port=80): Read timed out. (read timeout=5)
# Processed 660/933 tracks...
# Processed 670/933 tracks...
# Processed 680/933 tracks...
# Processed 690/933 tracks...
# Processed 700/933 tracks...
# Processed 710/933 tracks...
# Processed 720/933 tracks...
# Processed 730/933 tracks...
# Processed 740/933 tracks...
# Processed 750/933 tracks...
# Processed 760/933 tracks...
# Failed for Tech N9ne Collabos - Dysfunctional: HTTPConnectionPool(host='ws.audioscrobbler.com', port=80): Read timed out. (read timeout=5)
# Processed 770/933 tracks...
# Processed 780/933 tracks...
# Processed 790/933 tracks...
# Processed 800/933 tracks...
# Processed 810/933 tracks...
# Processed 820/933 tracks...
# Processed 830/933 tracks...
# Processed 840/933 tracks...
# Processed 850/933 tracks...
# Processed 860/933 tracks...
# Processed 870/933 tracks...
# Processed 880/933 tracks...
# Processed 890/933 tracks...
# Processed 900/933 tracks...
# Processed 910/933 tracks...
# Processed 920/933 tracks...
# Processed 930/933 tracks...
#
# Tracks with tags: 221/933
# Tag matrix shape: (933, 278)
# Total unique tags found: 278

# %%
# Visualize feature distribution
# Sum up how many tracks belong to each genre
tag_counts = np.array(tag_matrix.sum(axis=0)).flatten()
tag_names = mlb.classes_

# Get top 20 genres
top_indices = tag_counts.argsort()[::-1][:20]
top_tags = [tag_names[i] for i in top_indices]
top_counts = [tag_counts[i] for i in top_indices]

plt.figure(figsize=(12, 6))
sns.barplot(x=top_counts, y=top_tags, color='steelblue')
plt.title("Your Top 20 Music Tags by Track Count")
plt.xlabel("Number of Tracks")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 3: Build User Taste Profile & Recommend
# Average the tag vectors across all liked/top/recent tracks
# to create a single taste vector, then score Lastfm-generated
# candidates by cosine similarity against their Last.fm tags.

# %%
def get_lastfm_similar_tracks(artist, track, limit=100):
    # Gets similar tracks from Last.fm to use as recommendation candidates
    try:
        response = requests.get(LASTFM_BASE_URL, params={
            "method": "track.getSimilar",
            "artist": artist,
            "track": track,
            "api_key": LASTFM_API_KEY,
            "limit": limit,
            "format": "json"
        }, timeout=5)
        data = response.json()
        if 'error' in data or 'similartracks' not in data:
            return []
        return [
            {'name': t['name'], 'artist': t['artist']['name']}
            for t in data['similartracks']['track']
        ]
    except Exception as e:
        print(f"Similar tracks failed: {e}")
        return []


def build_recommendations(tracks, tag_matrix, mlb, n=10):
    # Full pipeline using Last.fm for both tags and candidates
    user_profile = tag_matrix.mean(axis=0).reshape(1, -1)

    # use top 10 tracks as seeds for similar track lookup
    candidates = []
    for track in tracks[:10]:
        similar = get_lastfm_similar_tracks(track['artist'], track['name'])
        candidates.extend(similar)
        time.sleep(0.25)

    # deduplicate candidates
    seen = set()
    unique_candidates = []
    for c in candidates:
        key = f"{c['name']}_{c['artist']}"
        if key not in seen:
            seen.add(key)
            unique_candidates.append(c)

    print(f"Total candidates: {len(unique_candidates)}")

    if not unique_candidates:
        print("No candidates found.")
        return []

    # fetch tags for candidates
    candidate_tags = []
    for c in unique_candidates:
        tags = get_lastfm_tags(c['artist'], c['name'])
        candidate_tags.append(tags)
        time.sleep(0.25)

    # encode with same vocabulary as user profile
    candidate_matrix = mlb.transform(candidate_tags)

    if candidate_matrix.sum() == 0:
        print("Warning: no candidate tags matched vocabulary.")
        return unique_candidates[:n]

    similarities = cosine_similarity(user_profile, candidate_matrix)[0]
    top_indices = similarities.argsort()[::-1][:n]

    recommendations = []
    for i in top_indices:
        recommendations.append({
            'name': unique_candidates[i]['name'],
            'artist': unique_candidates[i]['artist'],
            'similarity_score': round(float(similarities[i]), 4)
        })
    return recommendations

recommendations = build_recommendations(tracks, tag_matrix, mlb, n=10)
pd.DataFrame(recommendations)
# Out:
# Total candidates: 990
# C:\Users\Hamza\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:900: UserWarning: unknown class(es) ['1998', '2023', '2025', '<3', 'acoustic', 'adouo', 'afropiano', 'alicia keys', 'alt-pop', 'amapiano', 'amazing', 'american', 'amerie', 'amor a primeira ouvida', 'annie do sumato', 'anthem', 'atmospheric drum and bass', 'backstreet boys', 'ballad', 'baltimore club', 'balu_owns_this_song', 'best of 2013', 'best of 2016', 'best of 2024', 'best of 2025', 'better than addison rae', 'beyonce', 'big band', 'big bang', 'bigbang', 'blues', 'boy band', 'boy group', 'boybands', 'boys like girls', 'brandy', 'bubblegum bass', 'camila', 'cher', 'chill', 'cinematic', 'city pop', 'color', 'colors', 'colour', 'colours', 'country', 'country pop', 'darlingcore', 'destinys child', 'deth core', 'dobrado', 'dreamy', 'elle owns this song', 'emo-pop', 'epic', 'essaehdagiselledapandlr', 'eurodance', 'europop', 'experimental', 'fergie', 'folk', 'for our kids', 'funk carioca', 'future bass', 'get scared', 'go-go', 'goichi', 'grindcore', 'guts', 'gwen stefani', 'hawthorne heights', 'hiphop', 'hong joong ate', 'hong joong is fire breathing', 'hotgirlshit', 'if youre in the mood we can tip toe to the moon', 'indie folk', 'indie-rock', 'insane', 'instagram', 'intense', 'isa', 'jenopipizinho', 'jewel is hot', 'jun da nali', 'junhui da nali', 'justin timberlake', 'katy perry', 'kelly clarkson', 'key change', 'keyshia cole', 'kiss of life', 'kylie minogue', 'lesbians', 'lilith owns this music', 'linedance 2024', 'linedance 2025', 'linedance catalan', 'love song', 'lua core', 'madonna', 'makes me emotional', 'mamamoo', 'mariah carey', 'mario', 'mayasong', 'mcr', 'melancholy', 'michael jackson', 'miguel', 'mofiselle', 'motomano', 'musical', 'mxxhx', 'my chemical romance', 'ne-yo', 'nelly furtado', 'neo-psychedelia', 'neo-soul', 'new wave', 'nsync', 'one direction', 'pan', 'panic at the disco', 'piano', 'piano rock', 'pluggnb', 'pop pop pop', 'pop soul', 'post-hardcore', 'posthumous', 'powerpop', 'ptv', 'r&b', 'radio', 'rhythm and blues', 'ricky martin', 'right', 'rnb pop rap soul hiphop', 'ronnie radke', 'saw live', 'selena gomez', 'sex', 'shania twain', 'shoegaze', 'simple plan', 'singer-songwriter', 'ska', 'slappingitonyourtongue', 'slow burn', 'slow it down make it bouncy', 'songs i can actually listen to on repeat', 'soobin do joshua', 'sophisti-pop', 'special', 'spice girls', 'svt da nali', 'swedish', 'sweetener', 'synth pop', 'synthwave', 'sza', 't8s', 'taking back sunday', 'tear-jerker', 'teen pop', 'thank you badabes', 'the pussycat dolls', 'theo pretty boy da mafe', 'tlc', 'trap soul', 'trauma cinematográfico', 'treehouse', 'wb 3racha', 'whatdatmean', 'whiskey mouth all over my blonde south', 'whitney houston', 'yakousei', 'yellowcard', 'zara larsson', 'zayn'] will be ignored
#   warnings.warn(
#                    name             artist  similarity_score
# 0      Mystical Magical       Benson Boone            0.7224
# 1  Angel With A Shotgun            The Cab            0.6823
# 2           Just a Girl           No Doubt            0.6556
# 3             This Love           Maroon 5            0.6512
# 4        Sunday Morning           Maroon 5            0.6512
# 5     Since U Been Gone     Kelly Clarkson            0.6404
# 6           Don't Speak           No Doubt            0.6308
# 7               Mirrors  Justin Timberlake            0.6099
# 8  Too Good at Goodbyes          Sam Smith            0.6099
# 9            Bad Dreams        Teddy Swims            0.6099

# %%
# Visualize similarity scores
rec_df = pd.DataFrame(recommendations)

plt.figure(figsize=(10, 5))
sns.barplot(data=rec_df, x='similarity_score', y='name', color='steelblue')
plt.title("Top 10 Recommended Songs by Tag Similarity")
plt.xlabel("Cosine Similarity to Your Taste Profile")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
# API Endpoints
# Want to recommend songs based on the user's full taste profile 
# i.e. Liked Songs + Top Tracks + Recently Played combined
# API will be saved for .py files
