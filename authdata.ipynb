# %%
# Initial commit

# %%
import spotipy
from spotipy.oauth2 import Spotify0Auth
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import spotipy
# ----> 2 from spotipy.oauth2 import Spotify0Auth
#
# ImportError: cannot import name 'Spotify0Auth' from 'spotipy.oauth2' (C:\Users\Hamza\anaconda3\Lib\site-packages\spotipy\oauth2.py)
